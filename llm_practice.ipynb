# %%
import pandas as pd
import numpy as np

# %%
from openai import OpenAI

client = OpenAI()

# %%
response = client.responses.create(
    model="gpt-4.1-mini",   # fast + cost-efficient
    input="what is multi agent architecture. explain it in 4 points for a 20 year old. make it easy to understand.",
    max_output_tokens=200,
)
print("Response: \n", response.output_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 response = client.responses.create(
#       2     model="gpt-4.1-mini",   # fast + cost-efficient
#       3     input="what is multi agent architecture. explain it in 4 points for a 20 year old. make it easy to understand.",
#       4     max_output_tokens=200,
#       5 )
#       6 print("Response: \n", response.output_text)
#
# NameError: name 'client' is not defined
