# %%
import pandas as pd
import numpy as np

# %%
from openai import OpenAI

client = OpenAI()

# %%
response = client.responses.create(
    model="gpt-4.1-mini",   # fast + cost-efficient
    input="what is multi agent architecture. explain it in 4 points for a 20 year old. make it easy to understand.",
    max_output_tokens=200,
)
print("Response: \n", response.output_text)
# Out:
# Response:
#  Sure! Here’s a simple explanation of **multi-agent architecture** in 4 easy points:
#
# 1. **Many agents working together:** Instead of one big program doing everything, there are lots of smaller programs called "agents." Each agent does its own special job.
#
# 2. **Agents can talk to each other:** These agents communicate and share information, like teammates passing notes to get tasks done faster and better.
#
# 3. **Each agent is smart and independent:** Every agent can make decisions on its own, based on the information it has, without always waiting for instructions.
#
# 4. **Used to solve big problems:** By working together, these agents can handle complex tasks that one program alone would find too hard or slow.
#
# Basically, multi-agent architecture is like having a team of little computer helpers all working together to get something done!
